# %%
import pandas as pd
import os 
os.getcwd()
# Out:
# 'c:\\Users\\hamoud\\Documents\\OLIST-Brazilian_E-Commerce'

# %% [markdown]
# This script will iterate through all CSV files in the specified folder "./DATA/Raw_Data/".
# For each file, it reads the data into a pandas DataFrame, prints the list of columns, and identifies potential primary key columns by checking which columns contain only unique and non-null values.

# %% [markdown]
# If we have a dataset whithout a pk output, it is necessary to create one to ensure data integrity and enable reliable joins with other tables.
# If we have more than 1 in the output, it can be a composite key or a pk with a fk.

# %%
path = "./DATA/Raw_Data/"

for file_name in os.listdir(path):
    if file_name.endswith(".csv"):
        file_path = os.path.join(path, file_name)
        df = pd.read_csv(file_path)
        print(f"\nColumns in {file_name}:")
        print(list(df.columns))
        ppk = []
        for col in df.columns:
            if df[col].is_unique and df[col].notnull().all():
                ppk.append(col)
        print(f"Primary key(s) in {file_name}: {ppk}")
# Out:
# Columns in olist_customers_dataset.csv:
# ['customer_id', 'customer_unique_id', 'customer_zip_code_prefix', 'customer_city', 'customer_state']
# Primary key(s) in olist_customers_dataset.csv: ['customer_id']
#
# Columns in olist_geolocation_dataset.csv:
# ['geolocation_zip_code_prefix', 'geolocation_lat', 'geolocation_lng', 'geolocation_city', 'geolocation_state']
# Primary key(s) in olist_geolocation_dataset.csv: []
#
# Columns in olist_orders_dataset.csv:
# ['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date']
# Primary key(s) in olist_orders_dataset.csv: ['order_id', 'customer_id']
#
# Columns in olist_order_items_dataset.csv:
# ['order_id', 'order_item_id', 'product_id', 'seller_id', 'shipping_limit_date', 'price', 'freight_value']
# Primary key(s) in olist_order_items_dataset.csv: []
#
# Columns in olist_order_payments_dataset.csv:
# ['order_id', 'payment_sequential', 'payment_type', 'payment_installments', 'payment_value']
# Primary key(s) in olist_order_payments_dataset.csv: []
#
# Columns in olist_order_reviews_dataset.csv:
# ['review_id', 'order_id', 'review_score', 'review_comment_title', 'review_comment_message', 'review_creation_date', 'review_answer_timestamp']
# Primary key(s) in olist_order_reviews_dataset.csv: []
#
# Columns in olist_products_dataset.csv:
# ['product_id', 'product_category_name', 'product_name_lenght', 'product_description_lenght', 'product_photos_qty', 'product_weight_g', 'product_length_cm', 'product_height_cm', 'product_width_cm']
# Primary key(s) in olist_products_dataset.csv: ['product_id']
#
# Columns in olist_sellers_dataset.csv:
# ['seller_id', 'seller_zip_code_prefix', 'seller_city', 'seller_state']
# Primary key(s) in olist_sellers_dataset.csv: ['seller_id']
#
# Columns in product_category_name_translation.csv:
# ['product_category_name', 'product_category_name_english']
# Primary key(s) in product_category_name_translation.csv: ['product_category_name', 'product_category_name_english']
